# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
train_rewards = np.load("linear_rl_trader_rewards/train_v2_tech_indicators.npy")
test_rewards = np.load("linear_rl_trader_rewards/test_v2_tech_indicators.npy")
random_rewards = np.load("linear_rl_trader_rewards/random.npy")

# %%
rewards_df = pd.DataFrame({"train":train_rewards, "test":test_rewards, "random":random_rewards})

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20,5))

rewards_df["train"].plot(ax=axes[0])
axes[0].set_title('Portfolio value (train)')
rewards_df["test"].plot(ax=axes[1])
axes[1].set_title('Portfolio value (test)')
rewards_df["random"].plot(ax=axes[2])
axes[2].set_title('Portfolio value (random)')
# Out:
# Text(0.5, 1.0, 'Portfolio value (random)')

# %%
sns.displot(rewards_df)

# %%
idea

1. change linear to more complicated model
2. add more information to state vector (technical indicator, price yesterday)
3. use return instead of price for state vector
4. implement cross validation
5. tune hyperparam

# %%
train_rewards = np.load("linear_rl_trader_rewards/train_v1_no_tech_indicators.npy")
test_rewards = np.load("linear_rl_trader_rewards/test_v1_no_tech_indicators.npy")
random_rewards = np.load("linear_rl_trader_rewards/random.npy")

# %%
rewards_df = pd.DataFrame({"train":train_rewards, "test":test_rewards, "random":random_rewards})

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20,5))

rewards_df["train"].plot(ax=axes[0])
axes[0].set_title('Portfolio value (train)')
rewards_df["test"].plot(ax=axes[1])
axes[1].set_title('Portfolio value (test)')
rewards_df["random"].plot(ax=axes[2])
axes[2].set_title('Portfolio value (random)')
# Out:
# Text(0.5, 1.0, 'Portfolio value (random)')

# %%
sns.displot(rewards_df)

# %%
train_rewards = np.load("linear_rl_trader_rewards/train_vnn_1_w_tech_indicators.npy")
test_rewards = np.load("linear_rl_trader_rewards/test_vnn_1_w_tech_indicators.npy")
random_rewards = np.load("linear_rl_trader_rewards/random_vnn_1_w_tech_indicators.npy")

# %%
rewards_df = pd.DataFrame({"train":train_rewards, "test":test_rewards, "random":random_rewards})

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20,5))

rewards_df["train"].plot(ax=axes[0])
axes[0].set_title('Portfolio value (train)')
rewards_df["test"].plot(ax=axes[1])
axes[1].set_title('Portfolio value (test)')
rewards_df["random"].plot(ax=axes[2])
axes[2].set_title('Portfolio value (random)')
# Out:
# Text(0.5, 1.0, 'Portfolio value (random)')

# %%
rewards_df.describe()
# Out:
#                train          test        random
# count    2000.000000   2000.000000   2000.000000
# mean    65407.922769  27385.636297  26576.434644
# std     11334.209770   2015.934192   5394.453497
# min     27721.502385  20643.957001  13104.910130
# 25%     57288.474589  26381.575058  22763.807843
# 50%     65186.892179  27574.835417  25999.208484
# 75%     73500.491337  28465.907288  29799.339323
# max    100132.646737  35554.740982  53235.551228

# %%
sns.displot(rewards_df)

# %%
train_rewards = np.load("linear_rl_trader_rewards/train_vnn_1_no_tech_indicators.npy")
test_rewards = np.load("linear_rl_trader_rewards/test_vnn_1_no_tech_indicators.npy")
random_rewards = np.load("linear_rl_trader_rewards/random_vnn_1_w_tech_indicators.npy")

# %%
rewards_df = pd.DataFrame({"train":train_rewards, "test":test_rewards, "random":random_rewards})

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20,5))

rewards_df["train"].plot(ax=axes[0])
axes[0].set_title('Portfolio value (train)')
rewards_df["test"].plot(ax=axes[1])
axes[1].set_title('Portfolio value (test)')
rewards_df["random"].plot(ax=axes[2])
axes[2].set_title('Portfolio value (random)')
# Out:
# Text(0.5, 1.0, 'Portfolio value (random)')

# %%
rewards_df.describe()
# Out:
#               train          test        random
# count   2000.000000   2000.000000   2000.000000
# mean   46215.766594  27458.415137  26576.434644
# std     5991.581204   5098.439328   5394.453497
# min    23633.506000  15119.610000  13104.910130
# 25%    42168.586250  22751.712500  22763.807843
# 50%    45532.470300  28364.400000  25999.208484
# 75%    49930.999375  31498.485000  29799.339323
# max    76349.315800  40386.400000  53235.551228

# %%
sns.displot(rewards_df)

# %%
train_rewards = np.load("linear_rl_trader_rewards/train_vnn_2_no_tech_indicators.npy")
test_rewards = np.load("linear_rl_trader_rewards/test_vnn_2_no_tech_indicators.npy")
random_rewards = np.load("linear_rl_trader_rewards/random_vnn_1_w_tech_indicators.npy")

# %%
rewards_df = pd.DataFrame({"train":train_rewards, "test":test_rewards, "random":random_rewards})

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20,5))

rewards_df["train"].plot(ax=axes[0])
axes[0].set_title('Portfolio value (train)')
rewards_df["test"].plot(ax=axes[1])
axes[1].set_title('Portfolio value (test)')
rewards_df["random"].plot(ax=axes[2])
axes[2].set_title('Portfolio value (random)')
# Out:
# Text(0.5, 1.0, 'Portfolio value (random)')

# %%
rewards_df.describe()
# Out:
#               train          test        random
# count   2000.000000   2000.000000   2000.000000
# mean   49320.534953  21541.640420  26576.434644
# std     7646.690505   3712.420682   5394.453497
# min    28176.025300  16284.350000  13104.910130
# 25%    43907.109550  18040.640000  22763.807843
# 50%    48377.773750  20664.830000  25999.208484
# 75%    53804.925100  24111.057500  29799.339323
# max    85996.166000  37143.175000  53235.551228

# %%
sns.displot(rewards_df)

# %%
train_rewards = np.load("linear_rl_trader_rewards/train_vnn_3_no_tech_indicators.npy")
test_rewards = np.load("linear_rl_trader_rewards/test_vnn_3_no_tech_indicators.npy")
random_rewards = np.load("linear_rl_trader_rewards/random_vnn_3_w_tech_indicators.npy")

# %%
rewards_df = pd.DataFrame({"train":train_rewards, "test":test_rewards, "random":random_rewards})

# %%
rewards_df.describe()
# Out:
#               train          test        random
# count   2000.000000   2000.000000   2000.000000
# mean   42933.767775  20517.926027  23222.411043
# std     6551.197095   1496.409151   4500.448578
# min    23706.536819  13641.355003  11782.683332
# 25%    38330.813621  19778.907867  20075.518665
# 50%    42759.514323  20768.305954  22767.906180
# 75%    47372.635756  21393.241912  25978.604890
# max    72725.219555  26446.377653  46329.957867

# %%
sns.displot(rewards_df)

# %%
train_rewards = np.load("linear_rl_trader_rewards/train_vnn_3_w_tech_indicators.npy")
test_rewards = np.load("linear_rl_trader_rewards/test_vnn_3_w_tech_indicators.npy")
random_rewards = np.load("linear_rl_trader_rewards/random_vnn_3_no_tech_indicators.npy")

# %%
rewards_df = pd.DataFrame({"train":train_rewards, "test":test_rewards, "random":random_rewards})

# %%
rewards_df.describe()
# Out:
#               train          test        random
# count   2000.000000   2000.000000   2000.000000
# mean   60675.011016  22060.231947  23222.411043
# std    14282.525108   3453.424885   4500.448578
# min    22482.645862  14842.794149  11782.683332
# 25%    48120.681000  19929.081868  20075.518665
# 50%    61179.048915  20964.847408  22767.906180
# 75%    71678.407545  23531.256227  25978.604890
# max    96502.295492  35152.196487  46329.957867

# %%
sns.displot(rewards_df)
